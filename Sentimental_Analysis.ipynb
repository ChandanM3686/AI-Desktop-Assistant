# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandanM3686/AI-Desktop-Assistant/blob/main/Sentimental_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##flipkart Review sentimental Analysis
import pandas as pd
from transformers import pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
import string

# %%
encodings = ['utf-8', 'latin1', 'iso-8859-1', 'cp1252']
df = None

for encoding in encodings:
    try:
        df = pd.read_csv('/content/flipkart_product.csv', encoding=encoding)
        print(f"Successfully read the file with encoding: {encoding}")
        break
    except UnicodeDecodeError:
        print(f"Failed to read the file with encoding: {encoding}")
# Out:
# Failed to read the file with encoding: utf-8
# Successfully read the file with encoding: latin1

# %%
df.head(5)
# Out:
#                                          ProductName     Price Rate  \
# 0  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 1  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 2  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
# 3  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    1
# 4  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
#
#             Review                                            Summary
# 0           Super!  Great cooler.. excellent air flow and for this...
# 1          Awesome             Best budget 2 fit cooler. Nice cooling
# 2             Fair  The quality is good but the power of air is de...
# 3  Useless product                 Very bad product it's a only a fan
# 4             Fair                                      Ok ok product

# %%
df.isnull().any()
# Out:
# ProductName    False
# Price           True
# Rate            True
# Review          True
# Summary         True
# dtype: bool

# %%
df.dropna(inplace=True)

# %%
df.isnull().any()
# Out:
# ProductName    False
# Price          False
# Rate           False
# Review         False
# Summary        False
# dtype: bool

# %%
df['Review'][1]
# Out:
# 'Awesome'

# %%
def preprocess_text(text):
   tokens = word_tokenize(text)
   tokens = [word.lower() for word in tokens]
   tokens = [word for word in tokens if word.isalnum()]
   stop_words = set(stopwords.words('english'))
   tokens = [word for word in tokens if word not in stop_words]
   return ' '.join(tokens)

# %%
df['ProductName']=df['ProductName'].apply(preprocess_text)

# %%
train_reviews, test_reviews = train_test_split(df['ProductName'], test_size=0.2, random_state=42)

# %%
sentiment_pipeline = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
df.drop(columns=["Price","Summary"],inplace = True)

# %%
df.head(5)
# Out:
#                                          ProductName Rate           Review
# 0  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...    5           Super!
# 1  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...    5          Awesome
# 2  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...    3             Fair
# 3  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...    1  Useless product
# 4  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...    3             Fair

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Perform sentiment analysis on the reviews in the test set
test_sentiments = sentiment_pipeline(test_reviews.tolist())

# Convert the results to a DataFrame
sentiment_df = pd.DataFrame(test_sentiments)

# Display the sentiment analysis results
print(sentiment_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-a8ab5cec0038> in <cell line: 2>()
#       1 # Perform sentiment analysis on the reviews in the test set
# ----> 2 test_sentiments = sentiment_pipeline(test_reviews.tolist())
#       3
#       4 # Convert the results to a DataFrame
#       5 sentiment_df = pd.DataFrame(test_sentiments)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py in __call__(self, inputs, **kwargs)
#     154         """
#     155         inputs = (inputs,)
# --> 156         result = super().__call__(*inputs, **kwargs)
#     157         # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     158         _legacy = "top_k" not in kwargs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1233                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1234                 )
# -> 1235                 outputs = list(final_iterator)
#    1236                 return outputs
#    1237             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     123         # We're out of items within a batch
#     124         item = next(self.iterator)
# --> 125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#     127         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1159                 with inference_context():
#    1160                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1161                     model_outputs = self._forward(model_inputs, **forward_params)
#    1162                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1163             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py in _forward(self, model_inputs)
#     185         if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     186             model_inputs["use_cache"] = False
# --> 187         return self.model(**model_inputs)
#     188
#     189     def postprocess(self, model_outputs, function_to_apply=None, top_k=1, _legacy=True):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#     988         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     989
# --> 990         distilbert_output = self.distilbert(
#     991             input_ids=input_ids,
#     992             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     808                 attention_mask = torch.ones(input_shape, device=device)  # (bs, seq_length)
#     809
# --> 810         return self.transformer(
#     811             x=embeddings,
#     812             attn_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions, output_hidden_states, return_dict)
#     569                 )
#     570             else:
# --> 571                 layer_outputs = layer_module(
#     572                     hidden_state,
#     573                     attn_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, x, attn_mask, head_mask, output_attentions)
#     513
#     514         # Feed Forward Network
# --> 515         ffn_output = self.ffn(sa_output)  # (bs, seq_length, dim)
#     516         ffn_output: torch.Tensor = self.output_layer_norm(ffn_output + sa_output)  # (bs, seq_length, dim)
#     517
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in forward(self, input)
#     448
#     449     def forward(self, input: torch.Tensor) -> torch.Tensor:
# --> 450         return apply_chunking_to_forward(self.ff_chunk, self.chunk_size_feed_forward, self.seq_len_dim, input)
#     451
#     452     def ff_chunk(self, input: torch.Tensor) -> torch.Tensor:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     236         return torch.cat(output_chunks, dim=chunk_dim)
#     237
# --> 238     return forward_fn(*input_tensors)
#     239
#     240
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/distilbert/modeling_distilbert.py in ff_chunk(self, input)
#     453         x = self.lin1(input)
#     454         x = self.activation(x)
# --> 455         x = self.lin2(x)
#     456         x = self.dropout(x)
#     457         return x
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     114
#     115     def forward(self, input: Tensor) -> Tensor:
# --> 116         return F.linear(input, self.weight, self.bias)
#     117
#     118     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
import pandas as pd
from transformers import pipeline
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
import nltk

nltk.download('punkt')
nltk.download('stopwords')

encodings = ['utf-8', 'latin1', 'iso-8859-1', 'cp1252']
df = None

for encoding in encodings:
    try:
        df = pd.read_csv('/content/flipkart_product.csv', encoding=encoding)
        print(f"Successfully read the file with encoding: {encoding}")
        break
    except UnicodeDecodeError:
        print(f"Failed to read the file with encoding: {encoding}")

print(df.head(5))


def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens]

    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)


df['ProductName'] = df['ProductName'].apply(preprocess_text)


sentiment_pipeline = pipeline('sentiment-analysis')

df.drop(columns=["Price", "Summary"], inplace=True)


def predict_sentiment(review):
    preprocessed_review = preprocess_text(review)
    sentiment = sentiment_pipeline(preprocessed_review)[0]
    return sentiment

def main():
    print("Enter a review to predict its sentiment (type 'exit' to quit):")
    while True:
        user_review = input("Review: ")
        if user_review.lower() == 'exit':
            break
        sentiment = predict_sentiment(user_review)
        print(f"Sentiment: {sentiment['label']} (confidence: {sentiment['score']:.2f})")

if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Failed to read the file with encoding: utf-8
# Successfully read the file with encoding: latin1
#                                          ProductName     Price Rate  \
# 0  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 1  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    5
# 2  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
# 3  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    1
# 4  Candes 12 L Room/Personal Air Cooler?ÿ?ÿ(White...  ??3,999    3
#
#             Review                                            Summary
# 0           Super!  Great cooler.. excellent air flow and for this...
# 1          Awesome             Best budget 2 fit cooler. Nice cooling
# 2             Fair  The quality is good but the power of air is de...
# 3  Useless product                 Very bad product it's a only a fan
# 4             Fair                                      Ok ok product
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Enter a review to predict its sentiment (type 'exit' to quit):
# Review: Very very Bad. It's a fraud company and always bluffs. Will trap the customer with good lucrative offers to be delivered in the very same day. And then the game starts after taking the money. Fabricated details made available for shipping and delivery of goods. Customer care doest have any reply for delays and except for sorry they don't have any details and if you counter them then you are gone. The tickets will be closed without giving any resolution and fun is that the dates of resolution to be provided will keep on increasing if you keep on contacting them. Highly idiotic behaviour, response and service. It's a deliberate act of taking money and keeping with them without any delivery of product. Enjoying on customer,s money. BAD TO VERY BAD E-COMMERCE COMPANY. NEVER EVER FALL IN TRAP. ITS A TRAP. EVWRY ONE PLEASE BEWARE
# Sentiment: NEGATIVE (confidence: 1.00)
# Review: Trustworthy and Reliable Service Review: I stumbled upon Flipkart.com while searching for reliable online services, and I must say, I'm impressed. Their platform is user-friendly, and the process was seamless. The product quality surpassed my expectations, and their team ensured a smooth experience from start to finish. I feel confident recommending them to others. Keep up the excellent work! ⭐⭐⭐⭐⭐
# Sentiment: POSITIVE (confidence: 1.00)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-f53658b0275e> in <cell line: 61>()
#      60
#      61 if __name__ == "__main__":
# ---> 62     main()
#
# <ipython-input-43-f53658b0275e> in main()
#      53     print("Enter a review to predict its sentiment (type 'exit' to quit):")
#      54     while True:
# ---> 55         user_review = input("Review: ")
#      56         if user_review.lower() == 'exit':
#      57             break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
